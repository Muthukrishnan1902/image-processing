# %%
pip install imageio[pyav]
# Out:
# ...
#
# ...

# %%
import os
import warnings
warnings.simplefilter('ignore')

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.color import rgb2gray

# %%
kamal=os.listdir("D:/data/vijay/")
nani=os.listdir("D:/data/nani/")
tovino=os.listdir("D:/data/tovino thomas/")

# %%
limit=10
kamal_images=[None]*limit
j=0
for i in kamal:
    if(j<limit):
        kamal_images[j]=imread("D:/data/vijay/"+i)
        j+=1
    else:
        break

# %%
limit=10
nani_images=[None]*limit
j=0
for i in nani:
    if(j<limit):
        nani_images[j]=imread("D:/data/nani/"+i)
        j+=1
    else:
        break

# %%
limit=10
tovino_images=[None]*limit
j=0
for i in tovino:
    if(j<limit):
        tovino_images[j]=imread("D:/data/tovino thomas/"+i)
        j+=1
    else:
        break

# %%
imshow(kamal_images[4])

# %%
imshow(nani_images[5])

# %%
imshow(tovino_images[5])

# %%
kamal_gray=[None]*limit
j=0

for i in kamal:
    if(j<limit):
        kamal_gray[j]=rgb2gray(kamal_images[j][:,:,:3])
        j+=1
    else:
        break
kamal_gray[5].shape
# Out:
# (953, 1420)

# %%
nani_gray=[None]*limit
j=0

for i in nani:
    if(j<limit):
        nani_gray[j]=rgb2gray(nani_images[j][:,:,:3])
        j+=1
    else:
        break
nani_gray[7].shape
# Out:
# (850, 1300)

# %%
tovino_gray=[None]*limit
j=0

for i in tovino:
    if(j<limit):
        tovino_gray[j]=rgb2gray(tovino_images[j][:,:,:3])
        j+=1
    else:
        break
tovino_gray[8].shape
# Out:
# (859, 894)

# %%
imshow(kamal_gray[2])

# %%
imshow(nani_gray[2])

# %%
imshow(tovino_gray[2])

# %%
for j in range(10):
    rl=kamal_gray[j]
    kamal_gray[j]=resize(rl,(512,512))

# %%
for j in range(10):
    rl=nani_gray[j]
    nani_gray[j]=resize(rl,(512,512))

# %%
for j in range(10):
    rl=tovino_gray[j]
    tovino_gray[j]=resize(rl,(512,512))

# %%
imshow(kamal_gray[2])

# %%
imshow(nani_gray[6])

# %%
imshow(tovino_gray[5])

# %%
len_of_images_kamal=len(kamal_gray)

# %%
len_of_images_kamal
# Out:
# 10

# %%
image_size_kamal=kamal_gray[1].shape

# %%
image_size_kamal
# Out:
# (512, 512)

# %%
flatten_size_kamal=image_size_kamal[0]*image_size_kamal[1]

# %%
flatten_size_kamal
# Out:
# 262144

# %%
for i in range(len_of_images_kamal):
    kamal_gray[i]=np.ndarray.flatten(kamal_gray[i]).reshape(flatten_size_kamal,1)

# %%
kamal_gray=np.dstack(kamal_gray)
kamal_gray.shape
# Out:
# (262144, 1, 10)

# %%
kamal_gray=np.rollaxis(kamal_gray,axis=2,start=0)

# %%
kamal_gray.shape
# Out:
# (10, 262144, 1)

# %%
kamal_gray=kamal_gray.reshape(len_of_images_kamal,flatten_size_kamal)

# %%
kamal_gray.shape
# Out:
# (10, 262144)

# %%
kamal_data=pd.DataFrame(kamal_gray)

# %%
kamal_data
# Out:
#      0         1         2         3         4         5         6       \
# 0  0.267630  0.267630  0.267630  0.267629  0.267220  0.267492  0.269675
# 1  0.726737  0.726980  0.730396  0.730598  0.728670  0.721805  0.721219
# 2  0.408058  0.408058  0.408058  0.408093  0.408390  0.408398  0.408398
# 3  0.487732  0.487732  0.487732  0.487732  0.487732  0.487732  0.487732
# 4  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 5  0.999657  0.999439  0.999434  0.999303  0.998884  0.999114  0.999979
# 6  0.635880  0.657296  0.612710  0.603243  0.609022  0.609981  0.608721
# 7  0.510753  0.510753  0.510753  0.513648  0.514675  0.514675  0.512414
# 8  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 9  0.662397  0.675376  0.684672  0.691398  0.698521  0.706230  0.708729
#
#      7         8         9       ...    262134    262135    262136    262137  \
# 0  0.271049  0.271514  0.279809  ...  0.320109  0.322738  0.459778  0.760632
# ...

# %%
kamal_data["label"]="kamal"

# %%
kamal_data
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.267630  0.267630  0.267630  0.267629  0.267220  0.267492  0.269675
# 1  0.726737  0.726980  0.730396  0.730598  0.728670  0.721805  0.721219
# 2  0.408058  0.408058  0.408058  0.408093  0.408390  0.408398  0.408398
# 3  0.487732  0.487732  0.487732  0.487732  0.487732  0.487732  0.487732
# 4  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 5  0.999657  0.999439  0.999434  0.999303  0.998884  0.999114  0.999979
# 6  0.635880  0.657296  0.612710  0.603243  0.609022  0.609981  0.608721
# 7  0.510753  0.510753  0.510753  0.513648  0.514675  0.514675  0.512414
# 8  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 9  0.662397  0.675376  0.684672  0.691398  0.698521  0.706230  0.708729
#
#           7         8         9  ...    262135    262136    262137    262138  \
# 0  0.271049  0.271514  0.279809  ...  0.322738  0.459778  0.760632  0.812340
# ...

# %%
len_of_images_nani=len(nani_gray)
len_of_images_nani
# Out:
# 10

# %%
image_size_nani=nani_gray[1].shape
image_size_nani
# Out:
# (512, 512)

# %%
flatten_size_nani=image_size_nani[0]*image_size_nani[1]
flatten_size_nani
# Out:
# 262144

# %%
for i in range(len_of_images_nani):
    nani_gray[i]=np.ndarray.flatten(nani_gray[i]).reshape(flatten_size_nani,1)
nani_gray=np.dstack(nani_gray)
nani_gray.shape
# Out:
# (262144, 1, 10)

# %%
nani_gray=np.rollaxis(nani_gray,axis=2,start=0)
nani_gray.shape
# Out:
# (10, 262144, 1)

# %%
nani_gray=nani_gray.reshape(len_of_images_nani,flatten_size_nani)
nani_gray.shape
# Out:
# (10, 262144)

# %%
nani_data=pd.DataFrame(nani_gray)
nani_data
# Out:
#      0         1         2         3         4         5         6       \
# 0  0.683881  0.679903  0.675622  0.673729  0.674471  0.673779  0.673994
# 1  0.549158  0.545775  0.551433  0.548038  0.552897  0.549928  0.552191
# 2  0.906696  0.906696  0.908764  0.913128  0.914513  0.915084  0.915223
# 3  0.141769  0.132520  0.122070  0.119739  0.123043  0.118920  0.115956
# 4  0.626174  0.660650  0.690981  0.717557  0.740514  0.749236  0.754464
# 5  0.598670  0.580434  0.552052  0.516739  0.477193  0.446161  0.450001
# 6  0.359380  0.359380  0.359380  0.359354  0.358713  0.362208  0.362408
# 7  0.189989  0.194188  0.185424  0.180709  0.176002  0.167935  0.162044
# 8  0.716930  0.721018  0.726290  0.730662  0.732161  0.736103  0.741488
# 9  0.235331  0.238568  0.238688  0.242288  0.246117  0.246531  0.249855
#
#      7         8         9       ...    262134    262135    262136    262137  \
# 0  0.674798  0.669590  0.665865  ...  0.389690  0.417506  0.560931  0.388780
# ...

# %%
nani_data["label"]="nani"
nani_data
# Out:
#           0         1         2         3         4         5         6  \
# 0  0
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.683881  0.679903  0.675622  0.673729  0.674471  0.673779  0.673994
# 1   0.408058  0.408058  0.408058  0.408093  0.408390  0.408398  0.408398
# 2   0.141769  0.132520  0.122070  0.119739  0.123043  0.118920  0.115956
# 3   0.626174  0.660650  0.690981  0.717557  0.740514  0.749236  0.754464
# 4   0.549158  0.545775  0.551433  0.548038  0.552897  0.549928  0.552191
# 5   0.906696  0.906696  0.908764  0.913128  0.914513  0.915084  0.915223
# 6   0.662397  0.675376  0.684672  0.691398  0.698521  0.706230  0.708729
# 7   0.549158  0.545775  0.551433  0.548038  0.552897  0.549928  0.552191
# 8   0.510753  0.510753  0.510753  0.513648  0.514675  0.514675  0.512414
# 9   0.235331  0.238568  0.238688  0.242288  0.246117  0.246531  0.249855
# 10  0.635880  0.657296  0.612710  0.603243  0.609022  0.609981  0.608721
# 11  0.189989  0.194188  0.185424  0.180709  0.176002  0.167935  0.162044
# ...

# %%
x=south_actors.values[:,:-1]

# %%
y=south_actors.values[:,-1]

# %%
x
# Out:
# array([[0.6838810541273262, 0.6799025670991274, 0.6756215926204718, ...,
#         0.254599076928537, 0.2074687221334739, 0.16215176218119537],
#        [0.408058431372549, 0.408058431372549, 0.408058431372549, ...,
#         0.5884054867077384, 0.6003671118679987, 0.5160733962562257],
#        [0.14176891761736946, 0.13252019644424146, 0.12207011417142433,
#         ..., 0.06283308633536183, 0.06442070025020333,
#         0.06721612743421834],
#        ...,
#        [0.3593796161585149, 0.3593796161585149, 0.3593796161585149, ...,
#         0.9677661547750256, 0.9805839485925537, 0.9880780556237954],
#        [0.9996570525417446, 0.9994385354047944, 0.999434312676162, ...,
#         0.9999999999999998, 0.9999999999999998, 0.9999999999999998],
#        [0.23533069596832873, 0.23856837165383732, 0.2386877941176471,
#         ..., 0.6577802696078432, 0.676652818627451, 0.6878660539215686]],
#       dtype=object)

# %%
y
# Out:
# array(['tovino', 'kamal', 'tovino', 'tovino', 'nani', 'tovino', 'kamal',
#        'tovino', 'kamal', 'nani', 'kamal', 'tovino', 'tovino', 'tovino',
#        'kamal', 'nani', 'nani', 'nani', 'nani', 'nani', 'tovino', 'nani',
#        'nani', 'nani', 'kamal', 'nani', 'kamal', 'nani', 'nani', 'nani',
#        'nani', 'nani', 'nani', 'nani', 'kamal', 'kamal', 'nani', 'nani',
#        'kamal', 'tovino'], dtype=object)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
from sklearn import svm

# %%
clf=svm.SVC()

# %%
clf.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_pred=clf.predict(x_test)

# %%
y_pred
# Out:
# array(['nani', 'nani', 'nani', 'nani', 'kamal', 'nani', 'nani', 'nani',
#        'nani', 'nani', 'nani', 'kamal'], dtype=object)

# %%
for i in (np.random.randint(4,6,9)):
    predicted_images=(np.reshape(x_test[i],(512,512)).astype(np.float64))
    plt.title('predicted label:{0}'.format(y_pred[i]))
    plt.imshow(predicted_images,interpolation='nearest',cmap='gray')
    plt.show()

# %%
from sklearn import metrics

# %%
accuracy=metrics.accuracy_score(y_test,y_pred)

# %%
accuracy
# Out:
# 0.8333333333333334

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[2, 0, 0],
#        [0, 8, 0],
#        [0, 2, 0]], dtype=int64)
